# %% [markdown]
# ## Anova test between unemployee_rate of village in specific vital economic region

# %% [markdown]
# ### H0 : µ2 = µ3 = µ4 = µ5 = µ6 = µ7
# ### H1 : Tồn tại ít nhất một cặp khác nhau.
# ### Mức ý nghĩa α = 0.05

# %%
import pandas as pd 
import numpy as np
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
my_data = pd.read_csv("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/unemployeed_village.csv")

# %%
my_data
# Out:
#    Năm   Tổng số  Đồng bằng sông Hồng  Trung du và miền núi phía Bắc  \
# 0  2018     1.74                 1.44                           0.85
# 1  2019     1.69                 1.46                           0.98
# 2  2020     1.75                 1.45                           0.67
# 3  2021     2.50                 1.60                           2.34
# 4  2022     2.40                 1.49                           2.15
# 5  2023     1.99                 1.35                           1.86
#
#    Bắc Trung Bộ và duyên hải miền Trung  Tây Nguyên  Đông Nam Bộ  \
# 0                                  2.22        0.88         2.11
# 1                                  1.86        0.94         1.76
# 2                                  2.14        1.29         2.20
# 3                                  2.72        0.67         2.95
# 4                                  2.15        0.53         2.21
# 5                                  2.25        0.61         2.82
#
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Năm                                   6 non-null      int64
#  1   Tổng số                               6 non-null      float64
#  2   Đồng bằng sông Hồng                   6 non-null      float64
#  3   Trung du và miền núi phía Bắc         6 non-null      float64
#  4   Bắc Trung Bộ và duyên hải miền Trung  6 non-null      float64
#  5   Tây Nguyên                            6 non-null      float64
#  6   Đông Nam Bộ                           6 non-null      float64
#  7   Đồng bằng sông Cửu Long               6 non-null      float64
# dtypes: float64(7), int64(1)
# memory usage: 516.0 bytes

# %%
my_data[["Đồng bằng sông Hồng", "Trung du và miền núi phía Bắc", "Bắc Trung Bộ và duyên hải miền Trung", "Tây Nguyên", "Đông Nam Bộ", "Đồng bằng sông Cửu Long"]].describe()
# Out:
#        Đồng bằng sông Hồng  Trung du và miền núi phía Bắc  \
# count             6.000000                       6.000000
# mean              1.465000                       1.475000
# std               0.081179                       0.726051
# min               1.350000                       0.670000
# 25%               1.442500                       0.882500
# 50%               1.455000                       1.420000
# 75%               1.482500                       2.077500
# max               1.600000                       2.340000
#
#        Bắc Trung Bộ và duyên hải miền Trung  Tây Nguyên  Đông Nam Bộ  \
# count                              6.000000    6.000000     6.000000
# mean                               2.223333    0.820000     2.341667
# std                                0.279905    0.279142     0.453494
# min                                1.860000    0.530000     1.760000
# 25%                                2.142500    0.625000     2.132500
# ...

# %%
from scipy.stats import f_oneway

# %%
f_stat, p_value = f_oneway(my_data["Đồng bằng sông Hồng"], my_data["Trung du và miền núi phía Bắc"], my_data["Bắc Trung Bộ và duyên hải miền Trung"], my_data["Tây Nguyên"], my_data["Đông Nam Bộ"], my_data["Đồng bằng sông Cửu Long"])

# %%
print(f"F-statistic: {f_stat:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# F-statistic: 15.34
# P-value: 0.0000

# %%
if p_value < 0.05:
    print("Bác bỏ H0. Có sự khác biệt ý nghĩa giữa các nhóm.")
else:
    print("Không bác bỏ H0. Không có sự khác biệt ý nghĩa giữa các nhóm.")
# Out:
# Bác bỏ H0. Có sự khác biệt ý nghĩa giữa các nhóm.

# %%
tukey_data = pd.read_excel("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/unemployee_village_tukey.xlsx")

# %%
tukey_data
# Out:
#     unemployee_rate  area
# 0              1.44     2
# 1              1.46     2
# 2              1.45     2
# 3              1.60     2
# 4              1.49     2
# 5              1.35     2
# 6              0.85     3
# 7              0.98     3
# 8              0.67     3
# 9              2.34     3
# 10             2.15     3
# 11             1.86     3
# 12             2.22     4
# 13             1.86     4
# 14             2.14     4
# 15             2.72     4
# 16             2.15     4
# 17             2.25     4
# 18             0.88     5
# 19             0.94     5
# 20             1.29     5
# 21             0.67     5
# 22             0.53     5
# 23             0.61     5
# 24             2.11     6
# 25             1.76     6
# 26             2.20     6
# 27             2.95     6
# 28             2.21     6
# 29             2.82     6
# 30             2.37     7
# 31             2.60     7
# 32             2.53     7
# 33             3.82     7
# ...

# %%
tukey = pairwise_tukeyhsd(endog=tukey_data['unemployee_rate'], groups=tukey_data['area'], alpha=0.05)

# %%
tukey.plot_simultaneous()
import matplotlib.pyplot as plt
plt.title('Kiểm định Tukey về tỷ lệ thất nghiệp ở thành thị tại các vùng kinh tế trọng điểm')
plt.show()
