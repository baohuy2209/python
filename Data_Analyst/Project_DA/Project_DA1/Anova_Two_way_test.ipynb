# %% [markdown]
# # Anova Two Way test

# %%
import pandas as pd 
import numpy as np

# %%
amazon_data = pd.read_excel("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/amazon_data2.xlsx")

# %%
amazon_data = amazon_data.drop(columns=['seller_name.1'])

# %%
amazon_data.tail(10)
# Out:
#                                                  title         seller_name  \
# 982  Magnetic for iPhone SE Case 2022/3rd/2020/2nd ...       Pin¦¦¦hen¦¦¦S
# 983  Qloud Cloud Wrist Rest Keyboard – Cloud Palm R...        Cre¦¦¦-ab¦¦¦
# 984  Gel Pens, 6pcs 0.5mm Fine Point Smooth Writing...        Luc¦¦¦amb¦¦¦
# 985  LED Desk Lamp for Office Home, Eye-Caring Desk...       Air¦¦¦v S¦¦¦e
# 986  120 LED Selfie Light for Phone with Front & Ba...  RAY¦¦¦GE ¦¦¦ect¦¦¦
# 987  Pentel Arts Aquash Water Brush Assorted Tips, ...        Ama¦¦¦.co¦¦¦
# 988  Rubbermaid Spa Works Vanity Wastebasket, 2.25 ...        Ama¦¦¦.co¦¦¦
# 989  Brother HL-L3220CDW Wireless Compact Digital C...        Ama¦¦¦.co¦¦¦
# 990  Youbetia 360-Degree Rotate Pencil Holder, Offi...        You¦¦¦ia ¦¦¦
# 991  HTU?Upgraded Strongest Suction Car Phone Holde...        WBR¦¦¦tor¦¦¦
#
#                                            description  initial_price  \
# 982  PinLiSheng Designed for iPhone SE 2022/iPhone ...           5.99
# ...

# %%
def group_category(category): 
    if category in ['Office Products', 'Electronics', 'Tools & Home Improvement', 'Cell Phones & Accessories', 'Arts, Crafts & Sewing']: 
        return category
    else: 
        return 'Others'
amazon_data["root_bs_category"] = amazon_data["root_bs_category"].apply(lambda category: group_category(category))

# %%
amazon_data["country_of_origin"] = amazon_data["country_of_origin"].fillna("Other")

# %%
amazon_data
# Out:
#                                                  title     seller_name  \
# 0    HP OfficeJet 8015e Wireless Color All-in-One P...    Ama¦¦¦.co¦¦¦
# 1    Panasonic ErgoFit Wired Earbuds, In-Ear Headph...    Ama¦¦¦.co¦¦¦
# 2    LED Desk Lamp for Home Office, 3 Levels Dimmab...  Bes¦¦¦orl¦¦¦ED
# 3    C Charger Cable Fast Charging Phone Android Po...         NIN¦¦¦R
# 4    HOMOTEK 12 Pack Black Spring Door Stops,3-1/8"...         HOM¦¦¦K
# ..                                                 ...             ...
# 987  Pentel Arts Aquash Water Brush Assorted Tips, ...    Ama¦¦¦.co¦¦¦
# 988  Rubbermaid Spa Works Vanity Wastebasket, 2.25 ...    Ama¦¦¦.co¦¦¦
# 989  Brother HL-L3220CDW Wireless Compact Digital C...    Ama¦¦¦.co¦¦¦
# 990  Youbetia 360-Degree Rotate Pencil Holder, Offi...    You¦¦¦ia ¦¦¦
# 991  HTU?Upgraded Strongest Suction Car Phone Holde...    WBR¦¦¦tor¦¦¦
#
#                                            description  initial_price  \
# ...

# %%
amazon_data["country_of_origin"].unique()
# Out:
# array(['Thailand', 'China', 'Other', 'Taiwan', 'Philippines', 'USA',
#        'Japan', 'Korea, Republic of', 'Germany', 'Vietnam', 'Malaysia',
#        'Mexico', 'United Kingdom', 'Pakistan', 'Indonesia', 'Colombia',
#        'Hong Kong'], dtype=object)

# %%
anova_two_ways = {
    'Thailand': [
        amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Office Products'")["bought_past_month"].sum(), 
        amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Electronics'")["bought_past_month"].sum(), 
        amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Tools & Home Improvement'")["bought_past_month"].sum(), 
        amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Cell Phones & Accessories'")["bought_past_month"].sum(), 
        amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Arts, Crafts & Sewing'")["bought_past_month"].sum(), 
        amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Others'")["bought_past_month"].sum(), 
    ], 
    'China': [
        
    ], 
    'Other': [
        
    ], 
    'Taiwan': [

    ], 
    'Philippines': [
        
    ], 
    'USA': [
        
    ], 
    'Japan': [

    ], 
    'Korea, Republic of': [
        
    ], 
    'Germany': [
        
    ], 
    'VietNam': [
        
    ], 
    'Malaysia': [
        
    ], 
    'Mexico': [
        
    ], 
    'United Kingdom': [
        
    ], 
    'Pakistan': [
        
    ], 
    'Indonesia': [
        
    ], 
    'Colombia': [
        
    ], 
    'Hong Kong': [
        
    ]
}

# %%
amazon_data.query("country_of_origin == 'Thailand' and root_bs_category == 'Office Products'")["bought_past_month"].sum()
# Out:
# 12700.0
