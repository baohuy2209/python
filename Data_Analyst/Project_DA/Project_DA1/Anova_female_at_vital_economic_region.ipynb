# %%
import pandas as pd 
import numpy as np
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
my_data = pd.read_csv("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/unemployeed_female.csv")

# %%
my_data
# Out:
#     Năm  Tổng số  Đồng bằng sông Hồng  Trung du và miền núi phía Bắc  \
# 0  2018     2.45                 1.91                           1.20
# 1  2019     2.26                 1.67                           0.96
# 2  2020     3.05                 2.27                           1.17
# 3  2021     3.26                 1.91                           2.12
# 4  2022     2.32                 1.79                           1.76
# 5  2023     2.25                 1.60                           1.77
#
#    Bắc Trung Bộ và duyên hải miền Trung  Tây Nguyên  Đông Nam Bộ  \
# 0                                  3.08        1.63         2.59
# 1                                  2.46        1.47         2.46
# 2                                  3.77        2.27         4.04
# 3                                  3.41        1.26         4.84
# 4                                  2.94        0.85         2.62
# 5                                  2.55        0.85         2.81
#
# ...

# %%
my_data[["Đồng bằng sông Hồng", "Trung du và miền núi phía Bắc", "Bắc Trung Bộ và duyên hải miền Trung", "Tây Nguyên", "Đông Nam Bộ", "Đồng bằng sông Cửu Long"]].describe()
# Out:
#        Đồng bằng sông Hồng  Trung du và miền núi phía Bắc  \
# count             6.000000                       6.000000
# mean              1.858333                       1.496667
# std               0.237353                       0.450629
# min               1.600000                       0.960000
# 25%               1.700000                       1.177500
# 50%               1.850000                       1.480000
# 75%               1.910000                       1.767500
# max               2.270000                       2.120000
#
#        Bắc Trung Bộ và duyên hải miền Trung  Tây Nguyên  Đông Nam Bộ  \
# count                              6.000000    6.000000     6.000000
# mean                               3.035000    1.388333     3.226667
# std                                0.501548    0.536374     0.979707
# min                                2.460000    0.850000     2.460000
# 25%                                2.647500    0.952500     2.597500
# ...

# %%
from scipy.stats import f_oneway

# %%
f_stat, p_value = f_oneway(my_data["Tổng số"], my_data["Đồng bằng sông Hồng"], my_data["Trung du và miền núi phía Bắc"], my_data["Bắc Trung Bộ và duyên hải miền Trung"], my_data["Tây Nguyên"], my_data["Đông Nam Bộ"], my_data["Đồng bằng sông Cửu Long"])

# %%
print(f"F-statistic: {f_stat:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# F-statistic: 14.86
# P-value: 0.0000

# %%
if p_value < 0.05:
    print("Bác bỏ H0. Có sự khác biệt ý nghĩa giữa các nhóm.")
else:
    print("Không bác bỏ H0. Không có sự khác biệt ý nghĩa giữa các nhóm.")
# Out:
# Bác bỏ H0. Có sự khác biệt ý nghĩa giữa các nhóm.

# %%
tukey_data = pd.read_excel("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/unemployee_female_tukey.xlsx")

# %%
tukey_data
# Out:
#     unemployee_rate  area
# 0              2.45     1
# 1              2.26     1
# 2              3.05     1
# 3              3.26     1
# 4              2.32     1
# 5              2.25     1
# 6              1.91     2
# 7              1.67     2
# 8              2.27     2
# 9              1.91     2
# 10             1.79     2
# 11             1.60     2
# 12             1.20     3
# 13             0.96     3
# 14             1.17     3
# 15             2.12     3
# 16             1.76     3
# 17             1.77     3
# 18             3.08     4
# 19             2.46     4
# 20             3.77     4
# 21             3.41     4
# 22             2.94     4
# 23             2.55     4
# 24             1.63     5
# 25             1.47     5
# 26             2.27     5
# 27             1.26     5
# 28             0.85     5
# 29             0.85     5
# 30             2.59     6
# 31             2.46     6
# 32             4.04     6
# 33             4.84     6
# ...

# %%
tukey = pairwise_tukeyhsd(endog=tukey_data['unemployee_rate'], groups=tukey_data['area'], alpha=0.05)

# %%
tukey.plot_simultaneous()
import matplotlib.pyplot as plt
plt.title('Kiểm định Tukey về tỷ lệ thất nghiệp ở giới nữ tại các vùng kinh tế trọng điểm')
plt.show()
