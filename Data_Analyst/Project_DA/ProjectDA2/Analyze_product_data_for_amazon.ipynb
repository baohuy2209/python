# %% [markdown]
# ## Analyze customer data of Amazon

# %%
import pandas as pd 
import numpy as np

# %%
amazon_data = pd.read_excel("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/amazon_data2.xlsx")

# %%
amazon_data = amazon_data.drop(columns=['seller_name.1'])

# %%
amazon_data.tail(10)
# Out:
#                                                  title         seller_name  \
# 982  Magnetic for iPhone SE Case 2022/3rd/2020/2nd ...       Pin¦¦¦hen¦¦¦S
# 983  Qloud Cloud Wrist Rest Keyboard – Cloud Palm R...        Cre¦¦¦-ab¦¦¦
# 984  Gel Pens, 6pcs 0.5mm Fine Point Smooth Writing...        Luc¦¦¦amb¦¦¦
# 985  LED Desk Lamp for Office Home, Eye-Caring Desk...       Air¦¦¦v S¦¦¦e
# 986  120 LED Selfie Light for Phone with Front & Ba...  RAY¦¦¦GE ¦¦¦ect¦¦¦
# 987  Pentel Arts Aquash Water Brush Assorted Tips, ...        Ama¦¦¦.co¦¦¦
# 988  Rubbermaid Spa Works Vanity Wastebasket, 2.25 ...        Ama¦¦¦.co¦¦¦
# 989  Brother HL-L3220CDW Wireless Compact Digital C...        Ama¦¦¦.co¦¦¦
# 990  Youbetia 360-Degree Rotate Pencil Holder, Offi...        You¦¦¦ia ¦¦¦
# 991  HTU?Upgraded Strongest Suction Car Phone Holde...        WBR¦¦¦tor¦¦¦
#
#                                            description  initial_price  \
# 982  PinLiSheng Designed for iPhone SE 2022/iPhone ...           5.99
# ...

# %%
amazon_data.describe()
# Out:
#        initial_price  final_price  reviews_count   root_bs_rank      rating  \
# count     992.000000   992.000000     992.000000     992.000000  992.000000
# mean       47.392984    38.919798    7807.363911    8971.768145    4.524093
# std        76.023231    64.091896   20860.343464   13512.068868    0.182023
# min         1.760000     1.590000      17.000000       2.000000    3.900000
# 25%        13.000000     9.990000     519.000000    1130.000000    4.400000
# 50%        22.000000    19.000000    1777.500000    4019.500000    4.500000
# 75%        41.000000    35.625000    5578.000000   10515.500000    4.700000
# max       700.000000   605.000000  269769.000000  119341.000000    5.000000
#
#        bought_past_month       bs_rank
# count         991.000000    992.000000
# mean         1784.762866    185.611895
# std          2886.780199   2832.505030
# min            50.000000      1.000000
# 25%           300.000000     10.000000
# 50%           700.000000     27.000000
# ...

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              992 non-null    object
#  1   seller_name        992 non-null    object
#  2   description        992 non-null    object
#  3   initial_price      992 non-null    float64
#  4   final_price        992 non-null    float64
#  5   reviews_count      992 non-null    int64
#  6   root_bs_rank       992 non-null    int64
#  7   rating             992 non-null    float64
#  8   bought_past_month  991 non-null    float64
#  9   root_bs_category   992 non-null    object
#  10  bs_rank            992 non-null    int64
#  11  country_of_origin  600 non-null    object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 93.1+ KB

# %%
unique_category = amazon_data["root_bs_category"].unique()
unique_category
# Out:
# array(['Office Products', 'Electronics', 'Tools & Home Improvement',
#        'Cell Phones & Accessories', 'Arts, Crafts & Sewing', 'Our Brands',
#        'Micro SD Memory Cards', 'Laptop Messenger & Shoulder Bags',
#        'Industrial & Scientific', 'Laptop Stands', 'Laptop Sleeves',
#        'Telephone Wires', 'Telephone Headsets',
#        'Portable Bluetooth Speakers', 'Laptop Briefcases', 'USB Cables',
#        'Video Games', 'Health & Household', 'Camera Privacy Covers',
#        'Sports & Outdoors', 'Lightning Cables', 'Laptop Backpacks',
#        'Home & Kitchen'], dtype=object)

# %%
len(unique_category)
# Out:
# 23

# %%
Office_Products = amazon_data[amazon_data["root_bs_category"] == "Office Products"]
Office_Products
# Out:
#                                                  title  \
# 0    HP OfficeJet 8015e Wireless Color All-in-One P...
# 4    HOMOTEK 12 Pack Black Spring Door Stops,3-1/8"...
# 11   QUTOOL Lumbar Support Pillow for Office Chair ...
# 14   OLIXIS Chest Wood File Cabinet Rolling Organiz...
# 15   AT-A-GLANCE 2025 Desk Calendar, Monthly, Desk ...
# ..                                                 ...
# 979  Officemate Standard Staples, 5 Boxes General P...
# 983  Qloud Cloud Wrist Rest Keyboard – Cloud Palm R...
# 984  Gel Pens, 6pcs 0.5mm Fine Point Smooth Writing...
# 989  Brother HL-L3220CDW Wireless Compact Digital C...
# 990  Youbetia 360-Degree Rotate Pencil Holder, Offi...
#
#                   seller_name  \
# 0                Ama¦¦¦.co¦¦¦
# 4                     HOM¦¦¦K
# 11   QUT¦¦¦ Co¦¦¦rt ¦¦¦¦¦¦¦¦¦
# 14               Ama¦¦¦.co¦¦¦
# 15                   fli¦¦¦st
# ..                        ...
# 979              Ama¦¦¦.co¦¦¦
# 983              Cre¦¦¦-ab¦¦¦
# ...

# %%
Office_Products.describe()
# Out:
#        initial_price  final_price  reviews_count  root_bs_rank      rating  \
# count     531.000000   531.000000     531.000000     531.00000  531.000000
# mean       55.562957    46.503785    3064.094162   13057.93032    4.550282
# std        93.408058    80.345463    7081.787158   15740.26552    0.190369
# min         1.760000     1.760000      17.000000       7.00000    3.900000
# 25%        12.000000     9.900000     378.000000    3003.50000    4.400000
# 50%        21.000000    17.000000    1172.000000    7716.00000    4.600000
# 75%        45.000000    36.000000    2908.000000   17550.50000    4.700000
# max       700.000000   605.000000  103262.000000  119341.00000    4.900000
#
#        bought_past_month     bs_rank
# count         531.000000  531.000000
# mean         1100.659134   31.278719
# std          2506.275998   26.653569
# min            50.000000    1.000000
# 25%           200.000000    9.000000
# 50%           500.000000   24.000000
# ...

# %%
Office_Products["rating"].median()
# Out:
# 4.6

# %%
Office_Products.to_csv("C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/category_office_products.csv")

# %%
Electronics = amazon_data[amazon_data["root_bs_category"] == "Electronics"]
Electronics
# Out:
#                                                  title    seller_name  \
# 1    Panasonic ErgoFit Wired Earbuds, In-Ear Headph...   Ama¦¦¦.co¦¦¦
# 17   JBL Clip 4, Black/Orange - Portable Bluetooth ...        Hup¦¦¦s
# 19   Soundcore by Anker P20i True Wireless Earbuds,...   Ank¦¦¦ire¦¦¦
# 33   Damex Updated Thickened Solo Wireless 2/3 Repl...          Damex
# 34   Link Dream Replacement Ear Pads for Beats Solo...          yaanl
# ..                                                 ...            ...
# 950  JBL Flip 6 - Portable Bluetooth Speaker, power...   Ama¦¦¦.co¦¦¦
# 959  Portable Bluetooth Speaker with Lights, Powerf...   CHI¦¦¦CHY¦¦¦
# 960  TOZO A1 Mini Wireless Earbuds Bluetooth 5.3 in...        Des¦¦¦n
# 966  Replacement Earpads for Bose QC35 Replacement ...         MEI¦¦¦
# 981  Syncwire Headphone Splitter, Nylon-Braided Ext...  Syn¦¦¦re ¦¦¦p
#
#                                            description  initial_price  \
# ...

# %%
Electronics.to_csv('C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/category_electronics.csv', encoding='utf-8')

# %%
Tool_Home_Improvement = amazon_data[amazon_data["root_bs_category"] == "Tools & Home Improvement"]
Tool_Home_Improvement
# Out:
#                                                  title            seller_name  \
# 2    LED Desk Lamp for Home Office, 3 Levels Dimmab...         Bes¦¦¦orl¦¦¦ED
# 5    ?Upgraded? Dimmable Floor Lamp, 1000 Lumens LE...           Nin¦¦¦e-C¦¦¦
# 7    Govee Floor Lamp 2 with Matter, RGBIC Warm Coo...               Gov¦¦¦US
# 9    Simple Designs LD1003-BLK Basic Metal Desk Lam...           Ama¦¦¦.co¦¦¦
# 12   BOHON Desk Lamp 3 Color Modes 10 Brightness Di...  BoH¦¦¦Lig¦¦¦ng ¦¦¦¦¦¦
# ..                                                 ...                    ...
# 955  RUNTOP Floor Lamp with Shelves, Modern Shelf L...           RUN¦¦¦ US¦¦¦
# 964  Billconch Smart Gun Safe for Multiple Pistols ...           BIL¦¦¦NCH¦¦¦
# 967  Globe Electric 12641 Architect 32" Swing-Arm C...           Ama¦¦¦.co¦¦¦
# 978  Led Desk Lamp for Office Home - Eye Caring Arc...           FAN¦¦¦LUK¦¦¦
# 985  LED Desk Lamp for Office Home, Eye-Caring Desk...          Air¦¦¦v S¦¦¦e
#
# ...

# %%
Tool_Home_Improvement.to_csv('C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/category_toolhome.csv', encoding='utf-8')

# %%
cell_phones_accessories = amazon_data[amazon_data["root_bs_category"] == "Cell Phones & Accessories"]
cell_phones_accessories
# Out:
#                                                  title         seller_name  \
# 3    C Charger Cable Fast Charging Phone Android Po...             NIN¦¦¦R
# 8    Amazon Basics USB 3.1 USB-C to USB-A Female Ad...        Ama¦¦¦.co¦¦¦
# 10   Designed for iPhone 16 Pro Max Case, Compatibl...        Sym¦¦¦e U¦¦¦
# 18   JETech Case for iPhone 11 6.1-Inch, Non-Yellow...      JE ¦¦¦duc¦¦¦US
# 23   Compatible with iPhone 15 Pro Max Case Glitter...               BERFY
# ..                                                 ...                 ...
# 971  Solar Charger Power Bank 25000mAh - QC3.0 Fast...             Tra¦¦¦x
# 975  Silicone Suction Cup Phone Case Mount Double S...        kle¦¦¦ook¦¦¦
# 982  Magnetic for iPhone SE Case 2022/3rd/2020/2nd ...       Pin¦¦¦hen¦¦¦S
# 986  120 LED Selfie Light for Phone with Front & Ba...  RAY¦¦¦GE ¦¦¦ect¦¦¦
# 991  HTU?Upgraded Strongest Suction Car Phone Holde...        WBR¦¦¦tor¦¦¦
#
# ...

# %%
cell_phones_accessories.to_csv('C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/category_phone_accessories.csv', encoding='utf-8')

# %%
art_crafts_sewing= amazon_data[amazon_data["root_bs_category"] == "Arts, Crafts & Sewing"]
art_crafts_sewing
# Out:
#                                                  title            seller_name  \
# 6    AdTech 0453 2-Temp Dual Temperature Hot Glue G...           Ama¦¦¦.co¦¦¦
# 30   Mr. Pen Hot Glue Gun Kit - Glue Gun with 10 Gl...                Mr.¦¦¦n
# 97   ARTEZA Detail Paint Brushes, Set of 15, Fine D...           Ama¦¦¦.co¦¦¦
# 98   X-ACTO X3730Q X3000 Rubber-Barrel Hobby Knife,...           Ama¦¦¦.co¦¦¦
# 161  Bougimal 32 Pieces Paint Brush Set, Artist Ser...           Bou¦¦¦alU¦¦¦
# 171  Small Paint Brushes for Crafts, Paint Brushes ...           hai¦¦¦wen¦¦¦
# 227   Wooster 912-0031030020 Paintbrush, 2-Inch, White           Ama¦¦¦.co¦¦¦
# 228  Photomyne A4 Slide Viewer | Light Pad Backligh...          Pho¦¦¦yne¦¦¦D
# 232    Prang Washable Glue Stick, Clear.74 Oz, 1 Count           Uni¦¦¦Now¦¦¦
# 263  Scissors, Rkqoa 8" Scissors All Purpose 6 Pack...                  Rkqoa
# 338  Acrylic Paint Brush Set, 1 Packs / 10 pcs Wate...                  AROIC
# ...

# %%
art_crafts_sewing.to_csv('C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/category_artcraftsewing.csv', encoding='utf-8')

# %%
micro_sd_memory_cards= amazon_data[amazon_data["root_bs_category"] == "Micro SD Memory Cards"]
micro_sd_memory_cards
# Out:
#                                                  title  \
# 94   INLAND Micro Center 32GB Class 10 MicroSDHC Fl...
# 138  SanDisk 64GB Extreme microSDXC UHS-I Memory Ca...
# 449  Funturbo Ultimate Version SD2Vita 5.0 Memory C...
# 464  ROVE Ultimate Micro SD Card microSDXC 128GB Me...
# 724  SanDisk 128GB Ultra microSDXC UHS-I Memory Car...
# 796  PNY P-SDU128X2V31100PX-GE 128GB Premier-X Clas...
# 878  Lexar 32GB Micro SD Card 2 Pack, microSDHC UHS...
#
#                   seller_name  \
# 94               Mic¦¦¦Cen¦¦¦
# 138              Ama¦¦¦.co¦¦¦
# 449                  Fun¦¦¦bo
# 464             ROV¦¦¦ash¦¦¦m
# 724              Ama¦¦¦.co¦¦¦
# 796              Ama¦¦¦.co¦¦¦
# 878  YIS¦¦¦ TE¦¦¦OLO¦¦¦¦¦¦¦¦¦
#
#                                            description  initial_price  \
# 94   Fast Transfer Speeds With Class 10 speed ratin...          13.00
# 138  The SanDisk Extreme microSDXC memory card lets...          17.00
# ...

# %%
micro_sd_memory_cards.to_csv('C:/Users/ADMIN/BAOHUY/Phan_tich_du_lieu/category_microsdmemorycards.csv', encoding='utf-8')

# %%
laptop_messenger_shoulder_bags= amazon_data[amazon_data["root_bs_category"] == "Laptop Messenger & Shoulder Bags"]
laptop_messenger_shoulder_bags
# Out:
#                                                  title   seller_name  \
# 102  Mens Messenger Bag 15.6 Inch Waterproof Vintag...         LEGUO
# 207  ESTARER Messenger Bag for Men 17-17.3 Inch Lap...  Est¦¦¦r-U¦¦¦
#
#                                            description  initial_price  \
# 102  This laptop messenger bag is a perfect satchel...           70.0
# 207  Estarer Mens Laptop Messenger Bag 17-17.3 Inch...           68.0
#
#      final_price  reviews_count  root_bs_rank  rating  bought_past_month  \
# 102         50.0          13340            10     4.6             1000.0
# 207         47.0           4165            23     4.5              500.0
#
#                      root_bs_category  bs_rank country_of_origin
# 102  Laptop Messenger & Shoulder Bags       10             China
# 207  Laptop Messenger & Shoulder Bags       23             China

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
other_group=['Our Brands', 'Micro SD Memory Cards', 'Laptop Messenger & Shoulder Bags', 'Industrial & Scientific', 'Laptop Stands', 'Laptop Sleeves', 'Telephone Wires', 'Telephone Headsets']
print("Các loại mặt hàng khác")
other_group
# Out:
# Các loại mặt hàng khác
# ['Our Brands',
#  'Micro SD Memory Cards',
#  'Laptop Messenger & Shoulder Bags',
#  'Industrial & Scientific',
#  'Laptop Stands',
#  'Laptop Sleeves',
#  'Telephone Wires',
#  'Telephone Headsets']

# %%
def group_category(category): 
    if category in ['Office Products', 'Electronics', 'Tools & Home Improvement', 'Cell Phones & Accessories', 'Arts, Crafts & Sewing']: 
        return category
    else: 
        return 'Others'
amazon_data["root_bs_category"] = amazon_data["root_bs_category"].apply(lambda category: group_category(category))

# %%
dict_category={'Office Products':1, 'Electronics':2, 'Tools & Home Improvement':3,
       'Cell Phones & Accessories':4, 'Arts, Crafts & Sewing':5, 'Other': 6}
dict_category
# Out:
# {'Office Products': 1,
#  'Electronics': 2,
#  'Tools & Home Improvement': 3,
#  'Cell Phones & Accessories': 4,
#  'Arts, Crafts & Sewing': 5,
#  'Other': 6}

# %%
fig, ax = plt.subplots(1,1,figsize=(12,6))
g = sns.countplot(data = amazon_data, x = "root_bs_category", palette = "Blues", ax=ax)
for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')
g.set_xticklabels(dict_category)
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Số lượng")
plt.subplots_adjust(wspace=3, hspace=3)
g.set_title("Số lượng mua hàng của mỗi ngành hàng", fontsize=20)
plt.legend(dict_category, fontsize='small')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3064\2232288987.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.countplot(data = amazon_data, x = "root_bs_category", palette = "Blues", ax=ax)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3064\2232288987.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(dict_category)

# %%
mean_final_price_category = [
    round(Office_Products["final_price"].mean(),2), 
    round(Electronics["final_price"].mean(),2),
    round(Tool_Home_Improvement["final_price"].mean(),2),
    round(cell_phones_accessories["final_price"].mean(),2),
    round(art_crafts_sewing["final_price"].mean(),2),
    round(amazon_data[amazon_data["root_bs_category"] == "Others"]["final_price"].mean(), 2)
]
mean_final_price_category
# Out:
# [46.5, 46.52, 51.08, 19.7, 12.25, 21.22]

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
chart_final=sns.barplot(x = "root_bs_category", y="final_price",data=amazon_data, ax=ax, color="#C2FFC7")
for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='left', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Trung bình")
plt.subplots_adjust(wspace=3, hspace=3)
chart_final.set_title("Trung bình giá cuối cùng của mỗi ngành hàng", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Trung bình giá cuối cùng của mỗi ngành hàng')

# %%
mean_init_price_category = [
    round(Office_Products["initial_price"].mean(),2), 
    round(Electronics["initial_price"].mean(),2),
    round(Tool_Home_Improvement["initial_price"].mean(),2),
    round(cell_phones_accessories["initial_price"].mean(),2),
    round(art_crafts_sewing["initial_price"].mean(),2),
    round(amazon_data[amazon_data["root_bs_category"] == "Others"]["initial_price"].mean(), 2)
]
mean_init_price_category
# Out:
# [55.56, 63.66, 60.61, 23.44, 15.71, 28.54]

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
chart_init=sns.barplot(x = "root_bs_category", y="initial_price",data=amazon_data, ax=ax, color="#FA4032")
for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='left', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Trung bình")
chart_init.set_title("Trung bình giá khởi đầu của mỗi ngành hàng", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Trung bình giá khởi đầu của mỗi ngành hàng')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
total_review = amazon_data.groupby('root_bs_category')['reviews_count'].sum().reset_index()
chart_init=sns.barplot(x = "root_bs_category", y="reviews_count",data=total_review, ax=ax, color="#CBDCEB")
for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Số lượt đánh giá")
plt.subplots_adjust(wspace=3, hspace=3)
chart_init.set_title("Tổng số lượt đánh giá mỗi ngành hàng", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tổng số lượt đánh giá mỗi ngành hàng')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
med_ratings = amazon_data.groupby('root_bs_category')['rating'].median().reset_index()
chart_init=sns.barplot(x = "root_bs_category", y="rating",data=med_ratings, ax=ax, color="#4CC9FE")
for p in ax.patches:
        ax.annotate(f'{p.get_height()}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Trung vị")
plt.subplots_adjust(wspace=3, hspace=3)
chart_init.set_title("Trung vị các lượt rating mỗi ngành hàng (1-5)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Trung vị các lượt rating mỗi ngành hàng (1-5)')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
total_buyed = amazon_data.groupby('root_bs_category')['bought_past_month'].sum().reset_index()
chart_init=sns.barplot(x = "root_bs_category", y="bought_past_month",data=total_buyed, ax=ax, color="#4CC9FE")
for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Lượng đã bán")
plt.subplots_adjust(wspace=3, hspace=3)
chart_init.set_title("Tổng số mặt hàng đã bán ra của mỗi ngành hàng", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tổng số mặt hàng đã bán ra của mỗi ngành hàng')

# %%
sns.pairplot(amazon_data)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sns.boxplot(data = amazon_data, x = 'root_bs_category', y = 'final_price', ax = ax)
plt.xticks(rotation=45)
plt.subplots_adjust(wspace=3, hspace=3)

# %%
matrix_corr = amazon_data[['initial_price', 'final_price','reviews_count', 'bought_past_month', 'root_bs_rank', 'bs_rank']].corr()
matrix_corr
# Out:
#                    initial_price  final_price  reviews_count  \
# initial_price           1.000000     0.979981      -0.046900
# final_price             0.979981     1.000000      -0.052287
# reviews_count          -0.046900    -0.052287       1.000000
# bought_past_month      -0.015551    -0.042109       0.338026
# root_bs_rank            0.210800     0.235176      -0.194768
# bs_rank                 0.043205     0.019835      -0.009213
#
#                    bought_past_month  root_bs_rank   bs_rank
# initial_price              -0.015551      0.210800  0.043205
# final_price                -0.042109      0.235176  0.019835
# reviews_count               0.338026     -0.194768 -0.009213
# bought_past_month           1.000000     -0.332036  0.001053
# root_bs_rank               -0.332036      1.000000 -0.032645
# bs_rank                     0.001053     -0.032645  1.000000

# %%
plt.figure(figsize=(5,3))
sns.heatmap(matrix_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix') 
plt.show()

# %%
chart_rating = sns.stripplot(data=amazon_data, x = 'root_bs_category', y = 'rating', color="#B7E0FF")
plt.xticks(rotation=45)
plt.xlabel("Ngành hàng")
plt.ylabel("Mức đánh giá")
plt.subplots_adjust(wspace=3, hspace=3)
chart_rating.set_title("Biểu đồ thể hiện mức độ rating của mỗi loại ngành hàng", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Biểu đồ thể hiện mức độ rating của mỗi loại ngành hàng')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# from scipy import stats

# %%
# Q1_review_count = amazon_data['reviews_count'].quantile(0.25)
# Q3_review_count = amazon_data['reviews_count'].quantile(0.75)
# IQR_review_count = Q3_review_count - Q1_review_count
# data_clean_outlier_final = amazon_data[(amazon_data['reviews_count'] >= (Q1_review_count - 1.5 * IQR_review_count)) & (amazon_data['reviews_count'] <= (Q3_review_count + 1.5 * IQR_review_count))]
# data_clean_outlier_final

# %%
# data_clean_outlier_final["bought_past_month"]= data_clean_outlier_final["bought_past_month"].fillna(data_clean_outlier_final["bought_past_month"].median())

# %%
# Y_bought_past_month = 1/data_clean_outlier_final['bought_past_month'] # Biến đầu vào
# X_reviews_count = data_clean_outlier_final[['reviews_count']]
# data_clean_outlier_final[Y_bought_past_month.isna()]

# %%
# X_reviews_count.isna()

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_reviews_count,Y_bought_past_month , test_size=0.2)
# model = LinearRegression()
# model.fit(X_train, y_train)
# print(model.score(X_test, y_test))
# y_pred = model.predict(X_test)
# mse = mean_squared_error(y_test, y_pred)
# r2 = r2_score(y_test, y_pred)       

# print(f'Mean Squared Error: {mse}')
# print(f'R-squared: {r2}')
# print(f'Intercept: {model.intercept_}')
# print(f'Coefficient: {model.coef_}')

# %%
# plt.scatter(X_test, y_test, color='blue', label='Actual data')  # Dữ liệu thực tế
# plt.plot(X_test, y_pred, color='red', label='Regression line')  # Đường hồi quy
# plt.xlabel('X')
# plt.ylabel('Y')
# plt.legend()
# plt.show()

# %%
X_init_price = 1/amazon_data[['initial_price']] # Biến đầu vào
Y_reviews_count = amazon_data['reviews_count']
X_init_price.isna()
Y_reviews_count.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# Name: reviews_count, Length: 992, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(X_init_price,Y_reviews_count, test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)       

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
print(f'Intercept: {model.intercept_}')
print(f'Coefficient: {model.coef_}')
# Out:
# -0.005059002759035369
# Mean Squared Error: 469207818.1805307
# R-squared: -0.005059002759035369
# Intercept: 7945.3499142371775
# Coefficient: [2438.3409928]

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual data')  # Dữ liệu thực tế
plt.plot(X_test, y_pred, color='red', label='Regression line')  # Đường hồi quy
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
